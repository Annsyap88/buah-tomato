# %% [markdown]
# <a href="https://colab.research.google.com/github/Annsyap88/buah-tomato/blob/Annsyap88-patch-1/buah_tomato_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/tomato2.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('/content/IMG-20210823-WA0140.jpg',0)

# %%
nilai_hist = cv2.calcHist([img],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(nilai_hist)
plt.title('gray')
# Out:
# Text(0.5, 1.0, 'gray')
